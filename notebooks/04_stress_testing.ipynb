# %% [markdown]
# # 04 Stress Testing
# Evaluate historical and parametric stress scenarios.

# %%
import pandas as pd

from sam.stress import run_stress_tests

prices = pd.read_parquet('../data/raw/us_largecap.parquet')
weights = pd.read_csv('../reports/portfolio/latest/weights.csv')
run_stress_tests(prices, weights)
