# %% [markdown]
# # 02 Portfolio Construction
# Compare long-only constructors on a common price panel.

# %%
import pandas as pd

from sam.portfolio import build_portfolio

prices = pd.read_parquet('../data/raw/us_largecap.parquet')
methods = ['equal_weight', 'inverse_volatility', 'minimum_variance', 'risk_parity', 'momentum_tilt']
{method: build_portfolio(prices, method=method) for method in methods}
