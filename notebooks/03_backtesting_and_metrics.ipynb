# %% [markdown]
# # 03 Backtesting And Metrics
# Run a vectorized backtest and inspect risk-adjusted returns.

# %%
import pandas as pd

from sam.backtest import run_backtest
from sam.config import load_backtest_config

prices = pd.read_parquet('../data/raw/us_largecap.parquet')
config = load_backtest_config('../configs/backtests/default.toml')
result = run_backtest(prices, config=config)
result.metrics
