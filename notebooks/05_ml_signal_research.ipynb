# %% [markdown]
# # 05 ML Signal Research
# Research walk-forward ML signals and compare them with classical quant portfolios.

# %%
import pandas as pd

from sam.config import load_ml_config
from sam.ml import train_model

prices = pd.read_parquet('../data/raw/us_largecap.parquet')
config = load_ml_config('../configs/ml/baseline.toml')
result = train_model(prices, config=config, out_dir='../models/notebook-baseline')
result.metrics.head()
